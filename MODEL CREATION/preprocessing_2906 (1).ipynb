# %% [markdown]
# Before running the file Upload all your data set on your goole drive in a zip format

# %%
#Mount our google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 🚀 Step 1: Install gdown (simple and reliable)
# !pip install --upgrade gdown

# 🚀 Step 2: Download your dataset from Google Drive
import gdown

file_id = "1LUXN1t7PCRCGDmA56W_M4kbpuV5SwCeq"
url = f"https://drive.google.com/uc?id={file_id}"
output = "datasets.zip"

print("📥 Downloading datasets...")
gdown.download(url, output, quiet=False)

# 🚀 Step 3: Unzip the dataset
# !unzip -q datasets.zip -d ./dataset_extracted
print("✅ Unzipped to ./dataset_extracted/")
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# 📥 Downloading datasets...
# Downloading...
# From (original): https://drive.google.com/uc?id=1LUXN1t7PCRCGDmA56W_M4kbpuV5SwCeq
# From (redirected): https://drive.google.com/uc?id=1LUXN1t7PCRCGDmA56W_M4kbpuV5SwCeq&confirm=t&uuid=0a502f9f-599e-46bf-aca9-ccd239439029
# To: /content/datasets.zip
# 100%|██████████| 464M/464M [00:06<00:00, 68.8MB/s]
# ✅ Unzipped to ./dataset_extracted/

# %%
import glob
import numpy as np
import cv2

# ✅ Correct dataset path
base_path = '/content/dataset_extracted/dataset 1/'

# ✅ Gather video files
real_videos = glob.glob(base_path + 'real/*.mp4')
fake_videos = glob.glob(base_path + 'fake/*.mp4')

# Combine both
video_files = real_videos + fake_videos

frame_counts = []

for video_file in video_files:
    cap = cv2.VideoCapture(video_file)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Skip broken or extremely short videos
    if total_frames < 100:
        continue

    frame_counts.append(total_frames)
    cap.release()

# ✅ Results
print(f"Total valid videos: {len(frame_counts)}")
if len(frame_counts) > 0:
    print(f"Average frames per video: {round(np.mean(frame_counts), 2)}")
    print(f"Min frames: {np.min(frame_counts)}")
    print(f"Max frames: {np.max(frame_counts)}")
else:
    print("No valid videos found. Check your path or frame threshold.")

# %%
# ---- Paste this entire cell into Colab and run ----
import os, glob, cv2, face_recognition
from tqdm.autonotebook import tqdm

# paths (adjust only if you want different locations)
SRC_ROOT = '/content/dataset_extracted/dataset 1'   # your dataset path (note the space)
OUT_DIR = '/content/drive/MyDrive/FF_REAL_Face_only_data'  # output on Drive

os.makedirs(OUT_DIR, exist_ok=True)
print("Source root:", SRC_ROOT)
print("Output dir:", OUT_DIR)
print("Output exists:", os.path.exists(OUT_DIR))

# find mp4s (recursive)
video_files = glob.glob(os.path.join(SRC_ROOT, '**', '*.mp4'), recursive=True)
print("MP4s found:", len(video_files))
for p in video_files[:50]:
    print(" -", p)

# frame generator
def frame_extract(path):
    cap = cv2.VideoCapture(path)
    if not cap.isOpened():
        print("[ERROR] cannot open video:", path)
        return
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            yield frame
    finally:
        cap.release()

# processing function
def create_face_videos(path_list, out_dir, max_frames_per_video=150):
    os.makedirs(out_dir, exist_ok=True)
    print("Processing", len(path_list), "videos ->", out_dir)
    for path in tqdm(path_list):
        name = os.path.basename(path)
        out_path = os.path.join(out_dir, name)

        if os.path.exists(out_path):
            print("Skipping (already exists):", out_path)
            continue

        out = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
        frames = []
        written = 0
        read_count = 0

        for idx, frame in enumerate(frame_extract(path)):
            if frame is None:
                continue
            read_count += 1
            if idx > max_frames_per_video:
                break
            frames.append(frame)

            if len(frames) == 4:
                # CPU HOG (no CUDA)
                faces_batch = [face_recognition.face_locations(f, model='hog') for f in frames]

                for i, face_locs in enumerate(faces_batch):
                    if not face_locs:
                        continue
                    top, right, bottom, left = face_locs[0]
                    h, w = frames[i].shape[:2]
                    top, left, bottom, right = max(0, top), max(0, left), min(h, bottom), min(w, right)
                    if bottom - top <= 0 or right - left <= 0:
                        continue
                    try:
                        face_img = frames[i][top:bottom, left:right]
                        face_img = cv2.resize(face_img, (112,112))
                        out.write(face_img)
                        written += 1
                    except Exception as e:
                        print("Crop/resize error for", name, "->", str(e))
                frames = []

        out.release()
        print(f"Processed: {name} | frames read: {read_count} | faces written: {written}")

# Run processing on all found videos
if len(video_files) == 0:
    print("\nNo mp4s found under the path. Please check the path or upload videos into it.")
else:
    create_face_videos(video_files, OUT_DIR)
# Out:
# Source root: /content/dataset_extracted/dataset 1
# Output dir: /content/drive/MyDrive/FF_REAL_Face_only_data
# Output exists: True
# MP4s found: 200
#  - /content/dataset_extracted/dataset 1/real/00014.mp4
#  - /content/dataset_extracted/dataset 1/real/00000.mp4
#  - /content/dataset_extracted/dataset 1/real/00099.mp4
#  - /content/dataset_extracted/dataset 1/real/00026.mp4
#  - /content/dataset_extracted/dataset 1/real/00038.mp4
#  - /content/dataset_extracted/dataset 1/real/00044.mp4
#  - /content/dataset_extracted/dataset 1/real/00058.mp4
#  - /content/dataset_extracted/dataset 1/real/00001.mp4
#  - /content/dataset_extracted/dataset 1/real/00008.mp4
#  - /content/dataset_extracted/dataset 1/real/00028.mp4
#  - /content/dataset_extracted/dataset 1/real/00037.mp4
#  - /content/dataset_extracted/dataset 1/real/00075.mp4
#  - /content/dataset_extracted/dataset 1/real/00069.mp4
#  - /content/dataset_extracted/dataset 1/real/00093.mp4
#  - /content/dataset_extracted/dataset 1/real/00006.mp4
#  - /content/dataset_extracted/dataset 1/real/00095.mp4
#  - /content/dataset_extracted/dataset 1/real/00034.mp4
#  - /content/dataset_extracted/dataset 1/real/00035.mp4
#  - /content/dataset_extracted/dataset 1/real/00051.mp4
#  - /content/dataset_extracted/dataset 1/real/00052.mp4
#  - /content/dataset_extracted/dataset 1/real/00042.mp4
#  - /content/dataset_extracted/dataset 1/real/00059.mp4
#  - /content/dataset_extracted/dataset 1/real/00017.mp4
#  - /content/dataset_extracted/dataset 1/real/00019.mp4
#  - /content/dataset_extracted/dataset 1/real/00065.mp4
#  - /content/dataset_extracted/dataset 1/real/00073.mp4
#  - /content/dataset_extracted/dataset 1/real/00088.mp4
#  - /content/dataset_extracted/dataset 1/real/00021.mp4
#  - /content/dataset_extracted/dataset 1/real/00092.mp4
#  - /content/dataset_extracted/dataset 1/real/00046.mp4
#  - /content/dataset_extracted/dataset 1/real/00015.mp4
#  - /content/dataset_extracted/dataset 1/real/00089.mp4
#  - /content/dataset_extracted/dataset 1/real/00047.mp4
#  - /content/dataset_extracted/dataset 1/real/00087.mp4
#  - /content/dataset_extracted/dataset 1/real/00070.mp4
#  - /content/dataset_extracted/dataset 1/real/00061.mp4
#  - /content/dataset_extracted/dataset 1/real/00031.mp4
#  - /content/dataset_extracted/dataset 1/real/00055.mp4
mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id6_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0009.mp4 | frames read: 152 | faces written: 144
# Processed: id0_id23_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id9_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0009.mp4 | frames read: 152 | faces written: 145
# Processed: id0_id9_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id26_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0008.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id9_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id26_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id23_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0008.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id23_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0009.mp4 | frames read: 152 | faces written: 142
# Processed: id0_id9_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id6_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id23_0009.mp4 | frames read: 152 | faces written: 145
# Processed: id0_id21_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id26_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id26_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id26_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0009.mp4 | frames read: 152 | faces written: 144
# Processed: id0_id26_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0009.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id23_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id6_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0009.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id6_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0008.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0009.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id17_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id9_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id23_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id9_0008.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id6_0009.mp4 | frames read: 152 | faces written: 144
# Processed: id0_id3_0002.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id21_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id20_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id16_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0005.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0001.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id4_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id9_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id3_0004.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id6_0006.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id9_0009.mp4 | frames read: 152 | faces written: 147
# Processed: id0_id9_0003.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0000.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id1_0009.mp4 | frames read: 152 | faces written: 139
# Processed: id0_id23_0007.mp4 | frames read: 152 | faces written: 148
# Processed: id0_id2_0001.mp4 | frames read: 152 | faces written: 148

# %%
import glob

video_files = glob.glob('/content/dataset_extracted/dataset 1/**/*.mp4', recursive=True)
print("Found videos:", len(video_files))
video_files[:10]
# Out:
# Found videos: 200
# ['/content/dataset_extracted/dataset 1/real/00014.mp4',
#  '/content/dataset_extracted/dataset 1/real/00000.mp4',
#  '/content/dataset_extracted/dataset 1/real/00099.mp4',
#  '/content/dataset_extracted/dataset 1/real/00026.mp4',
#  '/content/dataset_extracted/dataset 1/real/00038.mp4',
#  '/content/dataset_extracted/dataset 1/real/00044.mp4',
#  '/content/dataset_extracted/dataset 1/real/00058.mp4',
#  '/content/dataset_extracted/dataset 1/real/00001.mp4',
#  '/content/dataset_extracted/dataset 1/real/00008.mp4',
#  '/content/dataset_extracted/dataset 1/real/00028.mp4']

# %%
create_face_videos(video_files, '/content/drive/MyDrive/FF_REAL_Face_only_data/')
# Out:
# Processing 200 videos -> /content/drive/MyDrive/FF_REAL_Face_only_data/
#   0%|          | 0/200 [00:00<?, ?it/s]
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00014.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00099.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00026.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00038.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00044.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00058.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00008.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00028.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00037.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00075.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00069.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00093.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00095.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00034.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00035.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00051.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00052.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00042.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00059.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00017.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00019.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00065.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00073.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00088.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00021.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00092.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00046.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00015.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00089.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00047.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00087.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00070.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00061.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00031.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00055.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00096.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00082.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00094.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00074.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00018.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00029.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00045.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00090.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00027.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00076.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00020.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00080.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00033.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00057.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00025.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00086.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00010.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00039.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00043.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00036.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00072.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00024.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00022.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00054.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00011.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00023.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00013.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00084.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00053.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00091.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00067.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00085.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00016.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00030.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00048.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00063.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00049.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00040.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00071.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00012.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00098.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00083.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00097.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00066.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00077.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00041.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00064.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00068.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00081.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00062.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00056.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00050.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00060.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00078.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00032.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/00079.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id6_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id23_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id26_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0008.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id26_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id23_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0008.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id23_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id6_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id23_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id26_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id26_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id26_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id26_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id23_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id6_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id6_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0008.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id17_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id23_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0008.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id6_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0002.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id21_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id20_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id16_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0005.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0001.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id4_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id3_0004.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id6_0006.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id9_0003.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0000.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id1_0009.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id23_0007.mp4
# Skipping (already exists): /content/drive/MyDrive/FF_REAL_Face_only_data/id0_id2_0001.mp4
